# %% [markdown]
# # Motivation & condition-stratified analysis
#
# - **Teaser (Fig. 1)** — visually-hard scenes where the deep path adds nothing.
# - **Condition-stratified AP (Table 1)** — SUPER−BASE gap by time-of-day / weather /
#   scene / crowd, showing the benefit is input-dependent but not explained by coarse
#   semantic categories.

# %%
# --- setup: run from the repo root with the kernel's own python ---
import os, sys
while not os.path.isdir(f'{os.getcwd()}/method02_advantage_regress_tinyConv'):
    os.chdir('..')          # walk up to the anydepth-yolov12 repo root
PY = sys.executable
print('cwd =', os.getcwd()); print('python =', PY)

# %% [markdown]
# ## Fig. 1 — motivation sample figure (BDD100K)
# `make_sample_figure_bdd.py`

# %%
# !{PY} -m method02_advantage_regress_tinyConv.make_sample_figure_bdd \
    --picks 'b4065fc4-ede06556,b216243d-55963da2' --out paper/fig_sample_routing.pdf

# %% [markdown]
# ## Table 1 — condition-stratified BASE vs SUPER AP
# `eval_condition_stratified_bdd.py` → json → `make_condition_table.py` → LaTeX.

# %%
# !{PY} -m method02_advantage_regress_tinyConv.eval_condition_stratified_bdd --help

# %%
# !{PY} -m method02_advantage_regress_tinyConv.make_condition_table --help
